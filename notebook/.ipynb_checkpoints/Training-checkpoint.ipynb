# %%
import os
import json

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.misc import imread

from keras.utils import to_categorical

# %%
data_path = os.path.join(os.getcwd(), '..','data', 'Augments_train')
Original_image_path = os.path.join(data_path, 'Original')
# Original_image_names = os.listdir(Original_image_path)
# Original_image_names.sort(key = lambda x:int(x.split('_')[2].split('.')[0]))

SegMask_path = os.path.join(data_path, 'SegMask_Wound_Bg')
# SegMask_names = os.listdir(SegMask_path)
# SegMask_names.sort(key = lambda x:int(x.split('_')[4].split('.')[0]))

# %%
# Testing
list(map(lambda x: x.split('_')[4], SegMask_names)) == list(map(lambda x: x.split('_')[2], Original_image_names))
# Out:
# True

# %%
SegMask_Raw_path = os.path.join(data_path, 'SegMask_Wound_Bg_Raw')
SegMask_Raw_names = os.listdir(SegMask_Raw_path)

# %% [markdown]
# # Image Data Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
image_datagen = ImageDataGenerator()
mask_datagen = ImageDataGenerator(preprocessing_function=to_categorical)

# %%
print(Original_image_path)
print(Original_image_names[0])
# Out:
# /home/renjie/Documents/GitHub/CascadedFCN/notebook/../data/Augments_train/Original
# 0

# %%
seed = 1

# %%
image_generator = train_datagen.flow_from_directory(Original_image_path, 
                                                    (480, 640),
                                                    class_mode= None,
                                                   seed = seed)
mask_generator = mask_datagen.flow_from_directory(SegMask_path,
                                                 (480,640),
                                                 color_mode = 'grayscale',
                                                 class_mode=None,
                                                 seed = seed)
# Out:
# Found 1000 images belonging to 1 classes.
# Found 1000 images belonging to 1 classes.

# %%
train_generator = zip(image_generator, mask_generator)

# %%
(image, mask) = next(train_generator)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-b0d24b22676c> in <module>()
# ----> 1 (image, mask) = next(train_generator)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py in __next__(self, *args, **kwargs)
#    1067
#    1068     def __next__(self, *args, **kwargs):
# -> 1069         return self.next(*args, **kwargs)
#    1070
#    1071     def _get_batches_of_transformed_samples(self, index_array):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py in next(self)
#    1475         # The transformation of images is not under thread lock
#    1476         # so it can be done in parallel
# -> 1477         return self._get_batches_of_transformed_samples(index_array)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py in _get_batches_of_transformed_samples(self, index_array)
#    1440             x = self.image_data_generator.random_transform(x)
#    1441             x = self.image_data_generator.standardize(x)
# -> 1442             batch_x[i] = x
#    1443         # optionally save augmented images to disk for debugging purposes
#    1444         if self.save_to_dir:
#
# ValueError: could not broadcast input array from shape (480,640,2) into shape (480,640,1)

# %%
image.shape, mask.shape
# Out:
# ((32, 480, 640, 3), (32, 480, 640, 1))

# %%
num = 0

# %%
num += 1

# %%
test_image = image[num]
test_image.shape
plt.imshow(test_image.astype('uint8'))

# %%
test_mask = mask[num]
print(test_mask.reshape([480,640]).shape)
plt.imshow(test_mask.reshape([480,640]).astype('uint8'))
# Out:
# (480, 640)
